# %%
from lstm_detection import DetectionTrainingModelPipeline, plot_learning_curve, plot_confusion_matrix
# Out:
# c:\Users\HP\Desktop\projects\TEG\env\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
pipeline = DetectionTrainingModelPipeline(configs='configs.json')
history = pipeline()
# Out:
# .........load_dataset is done.........
# .........scale_input_data is done.........
# .........lstm_data_transform is done.........
# .........split_data is done.........
# Epoch 1/100
# 8661/8661 [==============================] - 93s 10ms/step - loss: 0.0913 - binary_crossentropy: 0.0913 - val_loss: 0.0469 - val_binary_crossentropy: 0.0469
# Epoch 2/100
# 8661/8661 [==============================] - 76s 9ms/step - loss: 0.0352 - binary_crossentropy: 0.0352 - val_loss: 0.0375 - val_binary_crossentropy: 0.0375
# Epoch 3/100
# 8661/8661 [==============================] - 76s 9ms/step - loss: 0.0253 - binary_crossentropy: 0.0253 - val_loss: 0.0246 - val_binary_crossentropy: 0.0246
# Epoch 4/100
# 8661/8661 [==============================] - 77s 9ms/step - loss: 0.0213 - binary_crossentropy: 0.0213 - val_loss: 0.0213 - val_binary_crossentropy: 0.0213
# Epoch 5/100
# 8661/8661 [==============================] - 82s 9ms/step - loss: 0.0183 - binary_crossentropy: 0.0183 - val_loss: 0.0196 - val_binary_crossentropy: 0.0196
# Epoch 6/100
# 8661/8661 [==============================] - 83s 10ms/step - loss: 0.0169 - binary_crossentropy: 0.0169 - val_loss: 0.0180 - val_binary_crossentropy: 0.0180
# Epoch 7/100
# 8661/8661 [==============================] - 86s 10ms/step - loss: 0.0159 - binary_crossentropy: 0.0159 - val_loss: 0.0172 - val_binary_crossentropy: 0.0172
# Epoch 8/100
# 8661/8661 [==============================] - 83s 10ms/step - loss: 0.0150 - binary_crossentropy: 0.0150 - val_loss: 0.0165 - val_binary_crossentropy: 0.0165
# Epoch 9/100
# 8661/8661 [==============================] - 85s 10ms/step - loss: 0.0146 - binary_crossentropy: 0.0146 - val_loss: 0.0161 - val_binary_crossentropy: 0.0161
# Epoch 10/100
# 8661/8661 [==============================] - 88s 10ms/step - loss: 0.0140 - binary_crossentropy: 0.0140 - val_loss: 0.0162 - val_binary_crossentropy: 0.0162
# Epoch 11/100
# 8661/8661 [==============================] - 106s 12ms/step - loss: 0.0137 - binary_crossentropy: 0.0137 - val_loss: 0.0153 - val_binary_crossentropy: 0.0153
# Epoch 12/100
# 8661/8661 [==============================] - 104s 12ms/step - loss: 0.0134 - binary_crossentropy: 0.0134 - val_loss: 0.0155 - val_binary_crossentropy: 0.0155
# Epoch 13/100
# 8661/8661 [==============================] - 104s 12ms/step - loss: 0.0132 - binary_crossentropy: 0.0132 - val_loss: 0.0150 - val_binary_crossentropy: 0.0150
# Epoch 14/100
# 8661/8661 [==============================] - 193s 22ms/step - loss: 0.0131 - binary_crossentropy: 0.0131 - val_loss: 0.0149 - val_binary_crossentropy: 0.0149
# Epoch 15/100
# 8661/8661 [==============================] - 101s 12ms/step - loss: 0.0125 - binary_crossentropy: 0.0125 - val_loss: 0.0146 - val_binary_crossentropy: 0.0146
# Epoch 16/100
# 8661/8661 [==============================] - 105s 12ms/step - loss: 0.0127 - binary_crossentropy: 0.0127 - val_loss: 0.0161 - val_binary_crossentropy: 0.0161
# Epoch 17/100
# 8661/8661 [==============================] - 103s 12ms/step - loss: 0.0122 - binary_crossentropy: 0.0122 - val_loss: 0.0140 - val_binary_crossentropy: 0.0140
# Epoch 18/100
# 8661/8661 [==============================] - 103s 12ms/step - loss: 0.0122 - binary_crossentropy: 0.0122 - val_loss: 0.0141 - val_binary_crossentropy: 0.0141
# Epoch 19/100
# 8661/8661 [==============================] - 102s 12ms/step - loss: 0.0119 - binary_crossentropy: 0.0119 - val_loss: 0.0140 - val_binary_crossentropy: 0.0140
# Epoch 20/100
# 8661/8661 [==============================] - 95s 11ms/step - loss: 0.0119 - binary_crossentropy: 0.0119 - val_loss: 0.0144 - val_binary_crossentropy: 0.0144
# Epoch 21/100
# 8661/8661 [==============================] - 102s 12ms/step - loss: 0.0117 - binary_crossentropy: 0.0117 - val_loss: 0.0141 - val_binary_crossentropy: 0.0141
# Epoch 22/100
# 8661/8661 [==============================] - 97s 11ms/step - loss: 0.0116 - binary_crossentropy: 0.0116 - val_loss: 0.0135 - val_binary_crossentropy: 0.0135
# Epoch 23/100
# 8661/8661 [==============================] - 93s 11ms/step - loss: 0.0115 - binary_crossentropy: 0.0115 - val_loss: 0.0137 - val_binary_crossentropy: 0.0137
# Epoch 24/100
# 8661/8661 [==============================] - 98s 11ms/step - loss: 0.0115 - binary_crossentropy: 0.0115 - val_loss: 0.0139 - val_binary_crossentropy: 0.0139
# Epoch 25/100
# 8661/8661 [==============================] - 114s 13ms/step - loss: 0.0115 - binary_crossentropy: 0.0115 - val_loss: 0.0136 - val_binary_crossentropy: 0.0136
# Epoch 26/100
# 8661/8661 [==============================] - 90s 10ms/step - loss: 0.0114 - binary_crossentropy: 0.0114 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 27/100
# 8661/8661 [==============================] - 1394s 161ms/step - loss: 0.0112 - binary_crossentropy: 0.0112 - val_loss: 0.0136 - val_binary_crossentropy: 0.0136
# Epoch 28/100
# 8661/8661 [==============================] - 161s 19ms/step - loss: 0.0116 - binary_crossentropy: 0.0116 - val_loss: 0.0136 - val_binary_crossentropy: 0.0136
# Epoch 29/100
# 8661/8661 [==============================] - 142s 16ms/step - loss: 0.0111 - binary_crossentropy: 0.0111 - val_loss: 0.0135 - val_binary_crossentropy: 0.0135
# Epoch 30/100
# 8661/8661 [==============================] - 155s 18ms/step - loss: 0.0111 - binary_crossentropy: 0.0111 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 31/100
# 8661/8661 [==============================] - 146s 17ms/step - loss: 0.0110 - binary_crossentropy: 0.0110 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 32/100
# 8661/8661 [==============================] - 141s 16ms/step - loss: 0.0109 - binary_crossentropy: 0.0109 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 33/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0108 - binary_crossentropy: 0.0108 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 34/100
# 8661/8661 [==============================] - 150s 17ms/step - loss: 0.0109 - binary_crossentropy: 0.0109 - val_loss: 0.0150 - val_binary_crossentropy: 0.0150
# Epoch 35/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0107 - binary_crossentropy: 0.0107 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 36/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0107 - binary_crossentropy: 0.0107 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 37/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0107 - binary_crossentropy: 0.0107 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 38/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0108 - binary_crossentropy: 0.0108 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 39/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0106 - binary_crossentropy: 0.0106 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 40/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0106 - binary_crossentropy: 0.0106 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 41/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0105 - binary_crossentropy: 0.0105 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 42/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0105 - binary_crossentropy: 0.0105 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 43/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0105 - binary_crossentropy: 0.0105 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 44/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0104 - binary_crossentropy: 0.0104 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 45/100
# 8661/8661 [==============================] - 149s 17ms/step - loss: 0.0104 - binary_crossentropy: 0.0104 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 46/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0106 - binary_crossentropy: 0.0106 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 47/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0104 - binary_crossentropy: 0.0104 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 48/100
# 8661/8661 [==============================] - 148s 17ms/step - loss: 0.0105 - binary_crossentropy: 0.0105 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 49/100
# 8661/8661 [==============================] - 155s 18ms/step - loss: 0.0103 - binary_crossentropy: 0.0103 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 50/100
# 8661/8661 [==============================] - 149s 17ms/step - loss: 0.0103 - binary_crossentropy: 0.0103 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 51/100
# 8661/8661 [==============================] - 149s 17ms/step - loss: 0.0102 - binary_crossentropy: 0.0102 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 52/100
# 8661/8661 [==============================] - 149s 17ms/step - loss: 0.0102 - binary_crossentropy: 0.0102 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 53/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0103 - binary_crossentropy: 0.0103 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 54/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0102 - binary_crossentropy: 0.0102 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 55/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0102 - binary_crossentropy: 0.0102 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 56/100
# 8661/8661 [==============================] - 145s 17ms/step - loss: 0.0101 - binary_crossentropy: 0.0101 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 57/100
# 8661/8661 [==============================] - 156s 18ms/step - loss: 0.0101 - binary_crossentropy: 0.0101 - val_loss: 0.0128 - val_binary_crossentropy: 0.0128
# Epoch 58/100
# 8661/8661 [==============================] - 150s 17ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 59/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 60/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 61/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0102 - binary_crossentropy: 0.0102 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 62/100
# 8661/8661 [==============================] - 150s 17ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 63/100
# 8661/8661 [==============================] - 150s 17ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 64/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0128 - val_binary_crossentropy: 0.0128
# Epoch 65/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0101 - binary_crossentropy: 0.0101 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 66/100
# 8661/8661 [==============================] - 155s 18ms/step - loss: 0.0099 - binary_crossentropy: 0.0099 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 67/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 68/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0099 - binary_crossentropy: 0.0099 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 69/100
# 8661/8661 [==============================] - 155s 18ms/step - loss: 0.0098 - binary_crossentropy: 0.0098 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 70/100
# 8661/8661 [==============================] - 155s 18ms/step - loss: 0.0099 - binary_crossentropy: 0.0099 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 71/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - val_loss: 0.0135 - val_binary_crossentropy: 0.0135
# Epoch 72/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0098 - binary_crossentropy: 0.0098 - val_loss: 0.0128 - val_binary_crossentropy: 0.0128
# Epoch 73/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0097 - binary_crossentropy: 0.0097 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 74/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0097 - binary_crossentropy: 0.0097 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 75/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0097 - binary_crossentropy: 0.0097 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 76/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0097 - binary_crossentropy: 0.0097 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 77/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 78/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0097 - binary_crossentropy: 0.0097 - val_loss: 0.0131 - val_binary_crossentropy: 0.0131
# Epoch 79/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0135 - val_binary_crossentropy: 0.0135
# Epoch 80/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0098 - binary_crossentropy: 0.0098 - val_loss: 0.0134 - val_binary_crossentropy: 0.0134
# Epoch 81/100
# 8661/8661 [==============================] - 154s 18ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0139 - val_binary_crossentropy: 0.0139
# Epoch 82/100
# 8661/8661 [==============================] - 148s 17ms/step - loss: 0.0095 - binary_crossentropy: 0.0095 - val_loss: 0.0129 - val_binary_crossentropy: 0.0129
# Epoch 83/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0095 - binary_crossentropy: 0.0095 - val_loss: 0.0133 - val_binary_crossentropy: 0.0133
# Epoch 84/100
# 8661/8661 [==============================] - 153s 18ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0135 - val_binary_crossentropy: 0.0135
# Epoch 85/100
# 8661/8661 [==============================] - 152s 18ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132
# Epoch 86/100
# 8661/8661 [==============================] - 150s 17ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0137 - val_binary_crossentropy: 0.0137
# Epoch 87/100
# 8661/8661 [==============================] - 151s 17ms/step - loss: 0.0096 - binary_crossentropy: 0.0096 - val_loss: 0.0130 - val_binary_crossentropy: 0.0130
# Epoch 87: early stopping
# .........train_model is done.........

# %%
plot_learning_curve(
    dict_val = history.history,
    values = ['loss', 'val_loss'],
    x_label = 'epoch',
    y_label = 'loss',
    legend_list = ['train', 'test'],
    title = 'Model Loss',
    legend_loc = 'upper right'
)

# %%
plot_confusion_matrix(
    model = pipeline.model,
    x_train = pipeline.X_train,
    x_test = pipeline.X_test,
    y_train = pipeline.y_train,
    y_test = pipeline.y_test,
    label_list = ['No Leak', 'Leak']
)
# Out:
# 10826/10826 [==============================] - 83s 7ms/step
