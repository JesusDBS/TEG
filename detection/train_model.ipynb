# %%
from lstm_detection import DetectionTrainingModelPipeline, plot_learning_curve, plot_confusion_matrix
# Out:
# c:\Users\HP\Desktop\projects\TEG\env\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
pipeline = DetectionTrainingModelPipeline(configs='configs.json')
history = pipeline()
# Out:
# .........load_dataset is done.........
# .........scale_input_data is done.........
# .........lstm_data_transform is done.........
# .........split_data is done.........
# Epoch 1/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.1030 - binary_crossentropy: 0.1030 - val_loss: 0.0463 - val_binary_crossentropy: 0.0463
# Epoch 2/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0431 - binary_crossentropy: 0.0431 - val_loss: 0.0386 - val_binary_crossentropy: 0.0386
# Epoch 3/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0381 - binary_crossentropy: 0.0381 - val_loss: 0.0342 - val_binary_crossentropy: 0.0342
# Epoch 4/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0354 - binary_crossentropy: 0.0354 - val_loss: 0.0372 - val_binary_crossentropy: 0.0372
# Epoch 5/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0336 - binary_crossentropy: 0.0336 - val_loss: 0.0310 - val_binary_crossentropy: 0.0310
# Epoch 6/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0320 - binary_crossentropy: 0.0320 - val_loss: 0.0308 - val_binary_crossentropy: 0.0308
# Epoch 7/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0309 - binary_crossentropy: 0.0309 - val_loss: 0.0320 - val_binary_crossentropy: 0.0320
# Epoch 8/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0299 - binary_crossentropy: 0.0299 - val_loss: 0.0290 - val_binary_crossentropy: 0.0290
# Epoch 9/100
# 3337/3337 [==============================] - 28s 8ms/step - loss: 0.0291 - binary_crossentropy: 0.0291 - val_loss: 0.0283 - val_binary_crossentropy: 0.0283
# Epoch 10/100
# 3337/3337 [==============================] - 28s 9ms/step - loss: 0.0283 - binary_crossentropy: 0.0283 - val_loss: 0.0271 - val_binary_crossentropy: 0.0271
# Epoch 11/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0276 - binary_crossentropy: 0.0276 - val_loss: 0.0267 - val_binary_crossentropy: 0.0267
# Epoch 12/100
# 3337/3337 [==============================] - 28s 9ms/step - loss: 0.0272 - binary_crossentropy: 0.0272 - val_loss: 0.0268 - val_binary_crossentropy: 0.0268
# Epoch 13/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0267 - binary_crossentropy: 0.0267 - val_loss: 0.0267 - val_binary_crossentropy: 0.0267
# Epoch 14/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0264 - binary_crossentropy: 0.0264 - val_loss: 0.0266 - val_binary_crossentropy: 0.0266
# Epoch 15/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0258 - binary_crossentropy: 0.0258 - val_loss: 0.0261 - val_binary_crossentropy: 0.0261
# Epoch 16/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0255 - binary_crossentropy: 0.0255 - val_loss: 0.0271 - val_binary_crossentropy: 0.0271
# Epoch 17/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0252 - binary_crossentropy: 0.0252 - val_loss: 0.0267 - val_binary_crossentropy: 0.0267
# Epoch 18/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0249 - binary_crossentropy: 0.0249 - val_loss: 0.0263 - val_binary_crossentropy: 0.0263
# Epoch 19/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0246 - binary_crossentropy: 0.0246 - val_loss: 0.0245 - val_binary_crossentropy: 0.0245
# Epoch 20/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0243 - binary_crossentropy: 0.0243 - val_loss: 0.0247 - val_binary_crossentropy: 0.0247
# Epoch 21/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0243 - binary_crossentropy: 0.0243 - val_loss: 0.0237 - val_binary_crossentropy: 0.0237
# Epoch 22/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0240 - binary_crossentropy: 0.0240 - val_loss: 0.0267 - val_binary_crossentropy: 0.0267
# Epoch 23/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0239 - binary_crossentropy: 0.0239 - val_loss: 0.0242 - val_binary_crossentropy: 0.0242
# Epoch 24/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0235 - binary_crossentropy: 0.0235 - val_loss: 0.0260 - val_binary_crossentropy: 0.0260
# Epoch 25/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0235 - binary_crossentropy: 0.0235 - val_loss: 0.0251 - val_binary_crossentropy: 0.0251
# Epoch 26/100
# 3337/3337 [==============================] - 36s 11ms/step - loss: 0.0231 - binary_crossentropy: 0.0231 - val_loss: 0.0244 - val_binary_crossentropy: 0.0244
# Epoch 27/100
# 3337/3337 [==============================] - 45s 13ms/step - loss: 0.0233 - binary_crossentropy: 0.0233 - val_loss: 0.0240 - val_binary_crossentropy: 0.0240
# Epoch 28/100
# 3337/3337 [==============================] - 33s 10ms/step - loss: 0.0229 - binary_crossentropy: 0.0229 - val_loss: 0.0243 - val_binary_crossentropy: 0.0243
# Epoch 29/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0228 - binary_crossentropy: 0.0228 - val_loss: 0.0234 - val_binary_crossentropy: 0.0234
# Epoch 30/100
# 3337/3337 [==============================] - 32s 9ms/step - loss: 0.0226 - binary_crossentropy: 0.0226 - val_loss: 0.0251 - val_binary_crossentropy: 0.0251
# Epoch 31/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0225 - binary_crossentropy: 0.0225 - val_loss: 0.0252 - val_binary_crossentropy: 0.0252
# Epoch 32/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0224 - binary_crossentropy: 0.0224 - val_loss: 0.0234 - val_binary_crossentropy: 0.0234
# Epoch 33/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0222 - binary_crossentropy: 0.0222 - val_loss: 0.0231 - val_binary_crossentropy: 0.0231
# Epoch 34/100
# 3337/3337 [==============================] - 33s 10ms/step - loss: 0.0222 - binary_crossentropy: 0.0222 - val_loss: 0.0232 - val_binary_crossentropy: 0.0232
# Epoch 35/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0221 - binary_crossentropy: 0.0221 - val_loss: 0.0233 - val_binary_crossentropy: 0.0233
# Epoch 36/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0218 - binary_crossentropy: 0.0218 - val_loss: 0.0255 - val_binary_crossentropy: 0.0255
# Epoch 37/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0219 - binary_crossentropy: 0.0219 - val_loss: 0.0249 - val_binary_crossentropy: 0.0249
# Epoch 38/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0217 - binary_crossentropy: 0.0217 - val_loss: 0.0238 - val_binary_crossentropy: 0.0238
# Epoch 39/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0215 - binary_crossentropy: 0.0215 - val_loss: 0.0228 - val_binary_crossentropy: 0.0228
# Epoch 40/100
# 3337/3337 [==============================] - 29s 9ms/step - loss: 0.0215 - binary_crossentropy: 0.0215 - val_loss: 0.0231 - val_binary_crossentropy: 0.0231
# Epoch 41/100
# 3337/3337 [==============================] - 30s 9ms/step - loss: 0.0215 - binary_crossentropy: 0.0215 - val_loss: 0.0235 - val_binary_crossentropy: 0.0235
# Epoch 42/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0211 - binary_crossentropy: 0.0211 - val_loss: 0.0232 - val_binary_crossentropy: 0.0232
# Epoch 43/100
# 3337/3337 [==============================] - 32s 9ms/step - loss: 0.0214 - binary_crossentropy: 0.0214 - val_loss: 0.0226 - val_binary_crossentropy: 0.0226
# Epoch 44/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0211 - binary_crossentropy: 0.0211 - val_loss: 0.0240 - val_binary_crossentropy: 0.0240
# Epoch 45/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0209 - binary_crossentropy: 0.0209 - val_loss: 0.0252 - val_binary_crossentropy: 0.0252
# Epoch 46/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0209 - binary_crossentropy: 0.0209 - val_loss: 0.0238 - val_binary_crossentropy: 0.0238
# Epoch 47/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0208 - binary_crossentropy: 0.0208 - val_loss: 0.0233 - val_binary_crossentropy: 0.0233
# Epoch 48/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0210 - binary_crossentropy: 0.0210 - val_loss: 0.0232 - val_binary_crossentropy: 0.0232
# Epoch 49/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0207 - binary_crossentropy: 0.0207 - val_loss: 0.0229 - val_binary_crossentropy: 0.0229
# Epoch 50/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0206 - binary_crossentropy: 0.0206 - val_loss: 0.0233 - val_binary_crossentropy: 0.0233
# Epoch 51/100
# 3337/3337 [==============================] - 32s 9ms/step - loss: 0.0206 - binary_crossentropy: 0.0206 - val_loss: 0.0230 - val_binary_crossentropy: 0.0230
# Epoch 52/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0204 - binary_crossentropy: 0.0204 - val_loss: 0.0234 - val_binary_crossentropy: 0.0234
# Epoch 53/100
# 3337/3337 [==============================] - 32s 9ms/step - loss: 0.0206 - binary_crossentropy: 0.0206 - val_loss: 0.0231 - val_binary_crossentropy: 0.0231
# Epoch 54/100
# 3337/3337 [==============================] - 31s 9ms/step - loss: 0.0204 - binary_crossentropy: 0.0204 - val_loss: 0.0250 - val_binary_crossentropy: 0.0250
# Epoch 55/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0205 - binary_crossentropy: 0.0205 - val_loss: 0.0233 - val_binary_crossentropy: 0.0233
# Epoch 56/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0204 - binary_crossentropy: 0.0204 - val_loss: 0.0228 - val_binary_crossentropy: 0.0228
# Epoch 57/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0202 - binary_crossentropy: 0.0202 - val_loss: 0.0230 - val_binary_crossentropy: 0.0230
# Epoch 58/100
# 3337/3337 [==============================] - 32s 10ms/step - loss: 0.0201 - binary_crossentropy: 0.0201 - val_loss: 0.0244 - val_binary_crossentropy: 0.0244
# Epoch 58: early stopping
# .........train_model is done.........

# %%
plot_learning_curve(
    dict_val = history.history,
    values = ['loss', 'val_loss'],
    x_label = 'epoch',
    y_label = 'loss',
    legend_list = ['train', 'test'],
    title = 'Model Loss',
    legend_loc = 'upper right'
)

# %%
plot_confusion_matrix(
    model = pipeline.model,
    x_train = pipeline.X_train,
    x_test = pipeline.X_test,
    y_train = pipeline.y_train,
    y_test = pipeline.y_test,
    label_list = ['No Leak', 'Leak']
)
# Out:
# 4171/4171 [==============================] - 13s 3ms/step
